# %%
# %run DashboardClinica.py
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8060/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
